# %% [markdown]
# YOLO

# %%
import sys
import os
#  add project root to the path
sys.path.append(os.path.abspath('..'))
sys.path.append("../src") # add src directory to the path

import nest_asyncio
nest_asyncio.apply()  # Apply nest_asyncio to allow nested event loops

# %% [markdown]
# ### YOLO Detection

# %%
# import image detector function
from src.yolo_detector import run_detection
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Mesfin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:04<00:00, 1.35MB/s]

# %%
# Call the run_detection function to execute YOLO detection
if __name__ == "__main__":
    run_detection()
# Out:
# image 1/1 c:\ME\KAIM\week7\telegram-medical-analytics-pipeline\notebooks\data\raw\telegram_messages\images\CheMed123_10.jpg: 640x640 (no detections), 14846.3ms
# Speed: 883.0ms preprocess, 14846.3ms inference, 602.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\ME\KAIM\week7\telegram-medical-analytics-pipeline\notebooks\data\raw\telegram_messages\images\CheMed123_11.jpg: 640x640 1 clock, 570.9ms
# Speed: 28.5ms preprocess, 570.9ms inference, 1049.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\ME\KAIM\week7\telegram-medical-analytics-pipeline\notebooks\data\raw\telegram_messages\images\CheMed123_13.jpg: 640x640 4 hot dogs, 2 donuts, 578.0ms
# Speed: 63.4ms preprocess, 578.0ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\ME\KAIM\week7\telegram-medical-analytics-pipeline\notebooks\data\raw\telegram_messages\images\CheMed123_14.jpg: 640x480 (no detections), 864.6ms
# ...

# %% [markdown]
# ### Load YOLO detections into PostgreSQL

# %%
from src.load_yolo_to_postgres import load_detections, cur, conn

# %%
load_detections()
cur.close()
conn.close()
print("✅ YOLO detections loaded into Postgres")
# Out:
# ✅ YOLO detections loaded into Postgres
